# %%
# IMPORTANT NOTES BEFORE USE
# 1. This notebook should be run under a linux environment with a NVIDIA GPU. WSL2 is recommended.
# 2. CUDA 12.0 or higher is required. See https://docs.rapids.ai/install/#system-recommendations for more details.
# 3. Latest CUDA toolkit is recommended. See https://developer.nvidia.com/cuda-downloads for more details.
# 4. Python 3.10, 3.11, or 3.12 is required.
# 5. As referred to the RAPIDS documentation, RAPIDS pip packages require a recent version of pip that supports PEP600. If you encountered any problem, try upgrade pip with: pip install -U pip.
#       See https://docs.rapids.ai/install/#troubleshooting for more details.
# 6. It is STRONGLY RECOMMENDED to use a virtual environment (e.g., venv) to avoid package conflicts.

# Install dependencies
# %pip install \
    --extra-index-url=https://pypi.nvidia.com \
    "cudf-cu12==25.4.*" "cuml-cu12==25.4.*"
# %pip install opencv-python
# %pip install numpy
# %pip install pandas
# %pip install scikit-image
# %pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cudf-cu12==25.4.*
#   Downloading https://pypi.nvidia.com/cudf-cu12/cudf_cu12-25.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.9 MB/s eta 0:00:00a 0:00:010m
# Collecting cuml-cu12==25.4.*
#   Downloading https://pypi.nvidia.com/cuml-cu12/cuml_cu12-25.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 9.4 MB/s eta 0:00:00a 0:00:01
# Collecting cachetools (from cudf-cu12==25.4.*)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting cuda-python<13.0a0,>=12.6.2 (from cudf-cu12==25.4.*)
#   Using cached cuda_python-12.8.0-py3-none-any.whl.metadata (15 kB)
# Collecting cupy-cuda12x>=12.0.0 (from cudf-cu12==25.4.*)
#   Using cached cupy_cuda12x-13.4.1-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.6 kB)
# Collecting fsspec>=0.6.0 (from cudf-cu12==25.4.*)
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting libcudf-cu12==25.4.* (from cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/libcudf-cu12/libcudf_cu12-25.4.0-py3-none-manylinux_2_28_x86_64.whl (565.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.0/565.0 MB 43.8 MB/s eta 0:00:0000:0100:01
# Collecting numba-cuda<0.5.0a0,>=0.4.0 (from cudf-cu12==25.4.*)
#   Using cached numba_cuda-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting numba<0.62.0a0,>=0.59.1 (from cudf-cu12==25.4.*)
#   Using cached numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy<3.0a0,>=1.23 (from cudf-cu12==25.4.*)
#   Using cached numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting nvtx>=0.2.1 (from cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvtx/nvtx-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (562 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.6/562.6 kB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from cudf-cu12==25.4.*) (24.2)
# Collecting pandas<2.2.4dev0,>=2.0 (from cudf-cu12==25.4.*)
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting pyarrow<20.0.0a0,>=14.0.0 (from cudf-cu12==25.4.*)
#   Using cached pyarrow-19.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting pylibcudf-cu12==25.4.* (from cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/pylibcudf-cu12/pylibcudf_cu12-25.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 4.2 MB/s eta 0:00:0000:0100:01
# Collecting pynvjitlink-cu12 (from cudf-cu12==25.4.*)
#   Using cached pynvjitlink_cu12-0.5.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting rich (from cudf-cu12==25.4.*)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting rmm-cu12==25.4.* (from cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/rmm-cu12/rmm_cu12-25.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.6 MB/s eta 0:00:00
# Collecting typing_extensions>=4.0.0 (from cudf-cu12==25.4.*)
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting cuvs-cu12==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/cuvs-cu12/cuvs_cu12-25.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (711 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.1/711.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting dask-cuda==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/dask-cuda/dask_cuda-25.4.0-py3-none-any.whl (135 kB)
# Collecting dask-cudf-cu12==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/dask-cudf-cu12/dask_cudf_cu12-25.4.0-py3-none-any.whl (50 kB)
# Collecting joblib>=0.11 (from cuml-cu12==25.4.*)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting libcuml-cu12==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/libcuml-cu12/libcuml_cu12-25.4.0-py3-none-manylinux_2_28_x86_64.whl (424.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.6/424.6 MB 46.7 MB/s eta 0:00:0000:0100:01
# Collecting numba<0.62.0a0,>=0.59.1 (from cudf-cu12==25.4.*)
#   Using cached numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting nvidia-cublas-cu12 (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 42.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12 (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 38.4 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-curand-cu12 (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 42.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu12 (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 33.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12 (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 37.4 MB/s eta 0:00:0000:0100:01
# Collecting pylibraft-cu12==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/pylibraft-cu12/pylibraft_cu12-25.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (852 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.3/852.3 kB 17.5 MB/s eta 0:00:00
# Collecting raft-dask-cu12==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/raft-dask-cu12/raft_dask_cu12-25.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (288.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 MB 7.0 MB/s eta 0:00:0000:0100:02
# Collecting rapids-dask-dependency==25.4.* (from cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/rapids-dask-dependency/rapids_dask_dependency-25.4.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.8.0 (from cuml-cu12==25.4.*)
#   Using cached scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting treelite==4.4.1 (from cuml-cu12==25.4.*)
#   Using cached treelite-4.4.1-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting libcuvs-cu12==25.4.* (from cuvs-cu12==25.4.*->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/libcuvs-cu12/libcuvs_cu12-25.4.0-py3-none-manylinux_2_28_x86_64.whl (1182.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 GB 46.4 MB/s eta 0:00:0000:0100:01
# Collecting click>=8.1 (from dask-cuda==25.4.*->cuml-cu12==25.4.*)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting pynvml<13.0.0a0,>=12.0.0 (from dask-cuda==25.4.*->cuml-cu12==25.4.*)
#   Using cached pynvml-12.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting zict>=2.0.0 (from dask-cuda==25.4.*->cuml-cu12==25.4.*)
#   Using cached zict-3.0.0-py2.py3-none-any.whl.metadata (899 bytes)
# Collecting libkvikio-cu12==25.4.* (from libcudf-cu12==25.4.*->cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/libkvikio-cu12/libkvikio_cu12-25.4.0-py3-none-manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 50.8 MB/s eta 0:00:00
# Collecting librmm-cu12==25.4.* (from libcudf-cu12==25.4.*->cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/librmm-cu12/librmm_cu12-25.4.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 51.3 MB/s eta 0:00:00
# Collecting nvidia-nvcomp-cu12==4.2.0.11 (from libcudf-cu12==25.4.*->cudf-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-nvcomp-cu12/nvidia_nvcomp_cu12-4.2.0.11-py3-none-manylinux_2_28_x86_64.whl (46.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 MB 48.6 MB/s eta 0:00:00a 0:00:01
# Collecting rapids-logger==0.1.* (from libcudf-cu12==25.4.*->cudf-cu12==25.4.*)
#   Using cached rapids_logger-0.1.1-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting libraft-cu12==25.4.* (from libcuml-cu12==25.4.*->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/libraft-cu12/libraft_cu12-25.4.0-py3-none-manylinux_2_28_x86_64.whl (21.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 18.7 MB/s eta 0:00:00a 0:00:01
# Collecting distributed-ucxx-cu12==0.43.* (from raft-dask-cu12==25.4.*->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/distributed-ucxx-cu12/distributed_ucxx_cu12-0.43.0-py3-none-any.whl (25 kB)
# Collecting ucx-py-cu12==0.43.* (from raft-dask-cu12==25.4.*->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/ucx-py-cu12/ucx_py_cu12-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.3 MB/s eta 0:00:00a 0:00:010m
# Collecting dask==2025.2.0 (from rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached dask-2025.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting distributed==2025.2.0 (from rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached distributed-2025.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting cloudpickle>=3.0.0 (from dask==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting partd>=1.4.0 (from dask==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting toolz>=0.10.0 (from dask==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2>=2.10.3 (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting locket>=1.0.0 (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting msgpack>=1.0.2 (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: psutil>=5.8.0 in ./.venv/lib/python3.12/site-packages (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*) (7.0.0)
# Collecting sortedcontainers>=2.0.5 (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting tblib>=1.6.0 (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached tblib-3.1.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.2.0 in ./.venv/lib/python3.12/site-packages (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*) (6.4.2)
# Collecting urllib3>=1.26.5 (from distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting ucxx-cu12==0.43.* (from distributed-ucxx-cu12==0.43.*->raft-dask-cu12==25.4.*->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/ucxx-cu12/ucxx_cu12-0.43.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (714 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.4/714.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting libucx-cu12<1.19,>=1.15.0 (from ucx-py-cu12==0.43.*->raft-dask-cu12==25.4.*->cuml-cu12==25.4.*)
#   Using cached libucx_cu12-1.18.0-py3-none-manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Collecting libucxx-cu12==0.43.* (from ucxx-cu12==0.43.*->distributed-ucxx-cu12==0.43.*->raft-dask-cu12==25.4.*->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/libucxx-cu12/libucxx_cu12-0.43.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (515 kB)
# Collecting cuda-bindings~=12.8.0 (from cuda-python<13.0a0,>=12.6.2->cudf-cu12==25.4.*)
#   Using cached cuda_bindings-12.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting fastrlock>=0.5 (from cupy-cuda12x>=12.0.0->cudf-cu12==25.4.*)
#   Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba<0.62.0a0,>=0.59.1->cudf-cu12==25.4.*)
#   Using cached llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting numpy<3.0a0,>=1.23 (from cudf-cu12==25.4.*)
#   Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu12==25.4.*) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<2.2.4dev0,>=2.0->cudf-cu12==25.4.*)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<2.2.4dev0,>=2.0->cudf-cu12==25.4.*)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cufft-cu12->cuml-cu12==25.4.*)
#   Downloading https://pypi.nvidia.com/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 26.8 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0 (from rich->cudf-cu12==25.4.*)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich->cudf-cu12==25.4.*) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->cudf-cu12==25.4.*)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting nvidia-ml-py<13.0.0a0,>=12.0.0 (from pynvml<13.0.0a0,>=12.0.0->dask-cuda==25.4.*->cuml-cu12==25.4.*)
#   Using cached nvidia_ml_py-12.570.86-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<2.2.4dev0,>=2.0->cudf-cu12==25.4.*) (1.17.0)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.10.3->distributed==2025.2.0->rapids-dask-dependency==25.4.*->cuml-cu12==25.4.*)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Using cached treelite-4.4.1-py3-none-manylinux2014_x86_64.whl (922 kB)
# Using cached dask-2025.2.0-py3-none-any.whl (1.4 MB)
# Using cached distributed-2025.2.0-py3-none-any.whl (1.0 MB)
# Using cached rapids_logger-0.1.1-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (192 kB)
# Using cached cuda_python-12.8.0-py3-none-any.whl (11 kB)
# Using cached cupy_cuda12x-13.4.1-cp312-cp312-manylinux2014_x86_64.whl (105.3 MB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
# Using cached numba_cuda-0.4.0-py3-none-any.whl (453 kB)
# Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached pyarrow-19.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (42.1 MB)
# Using cached scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached pynvjitlink_cu12-0.5.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (46.2 MB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached cuda_bindings-12.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.2 MB)
# Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (53 kB)
# Using cached llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached pynvml-12.0.0-py3-none-any.whl (26 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached zict-3.0.0-py2.py3-none-any.whl (43 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached libucx_cu12-1.18.0-py3-none-manylinux_2_28_x86_64.whl (27.5 MB)
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
# Using cached nvidia_ml_py-12.570.86-py3-none-any.whl (44 kB)
# Using cached partd-1.4.2-py3-none-any.whl (18 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached tblib-3.1.0-py3-none-any.whl (12 kB)
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Installing collected packages: sortedcontainers, pytz, nvtx, nvidia-ml-py, libkvikio-cu12, fastrlock, cuda-bindings, zict, urllib3, tzdata, typing_extensions, toolz, tblib, rapids-logger, pyyaml, pynvml, pynvjitlink-cu12, pyarrow, nvidia-nvjitlink-cu12, nvidia-nvcomp-cu12, nvidia-curand-cu12, nvidia-cublas-cu12, numpy, msgpack, mdurl, MarkupSafe, locket, llvmlite, libucx-cu12, joblib, fsspec, cuda-python, cloudpickle, click, cachetools, ucx-py-cu12, scipy, partd, pandas, nvidia-cusparse-cu12, nvidia-cufft-cu12, numba, markdown-it-py, librmm-cu12, jinja2, cupy-cuda12x, treelite, rmm-cu12, rich, nvidia-cusolver-cu12, numba-cuda, libucxx-cu12, libcudf-cu12, dask, ucxx-cu12, pylibcudf-cu12, libraft-cu12, distributed, rapids-dask-dependency, pylibraft-cu12, libcuvs-cu12, cudf-cu12, libcuml-cu12, distributed-ucxx-cu12, dask-cudf-cu12, dask-cuda, cuvs-cu12, raft-dask-cu12, cuml-cu12
# Successfully installed MarkupSafe-3.0.2 cachetools-5.5.2 click-8.1.8 cloudpickle-3.1.1 cuda-bindings-12.8.0 cuda-python-12.8.0 cudf-cu12-25.4.0 cuml-cu12-25.4.0 cupy-cuda12x-13.4.1 cuvs-cu12-25.4.0 dask-2025.2.0 dask-cuda-25.4.0 dask-cudf-cu12-25.4.0 distributed-2025.2.0 distributed-ucxx-cu12-0.43.0 fastrlock-0.8.3 fsspec-2025.3.2 jinja2-3.1.6 joblib-1.4.2 libcudf-cu12-25.4.0 libcuml-cu12-25.4.0 libcuvs-cu12-25.4.0 libkvikio-cu12-25.4.0 libraft-cu12-25.4.0 librmm-cu12-25.4.0 libucx-cu12-1.18.0 libucxx-cu12-0.43.0 llvmlite-0.43.0 locket-1.0.0 markdown-it-py-3.0.0 mdurl-0.1.2 msgpack-1.1.0 numba-0.60.0 numba-cuda-0.4.0 numpy-2.0.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cufft-cu12-11.3.3.83 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-ml-py-12.570.86 nvidia-nvcomp-cu12-4.2.0.11 nvidia-nvjitlink-cu12-12.8.93 nvtx-0.2.11 pandas-2.2.3 partd-1.4.2 pyarrow-19.0.1 pylibcudf-cu12-25.4.0 pylibraft-cu12-25.4.0 pynvjitlink-cu12-0.5.2 pynvml-12.0.0 pytz-2025.2 pyyaml-6.0.2 raft-dask-cu12-25.4.0 rapids-dask-dependency-25.4.0 rapids-logger-0.1.1 rich-14.0.0 rmm-cu12-25.4.0 scipy-1.15.2 sortedcontainers-2.4.0 tblib-3.1.0 toolz-1.0.0 treelite-4.4.1 typing_extensions-4.13.2 tzdata-2025.2 ucx-py-cu12-0.43.0 ucxx-cu12-0.43.0 urllib3-2.4.0 zict-3.0.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in ./.venv/lib/python3.12/site-packages (from opencv-python) (2.0.2)
# Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit-image
#   Using cached scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.24 in ./.venv/lib/python3.12/site-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in ./.venv/lib/python3.12/site-packages (from scikit-image) (1.15.2)
# Collecting networkx>=3.0 (from scikit-image)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting pillow>=10.1 (from scikit-image)
#   Using cached pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Using cached tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in ./.venv/lib/python3.12/site-packages (from scikit-image) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Using cached scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
# Using cached tifffile-2025.3.30-py3-none-any.whl (226 kB)
# Installing collected packages: tifffile, pillow, networkx, lazy-loader, imageio, scikit-image
# Successfully installed imageio-2.37.0 lazy-loader-0.4 networkx-3.4.2 pillow-11.2.1 scikit-image-0.25.2 tifffile-2025.3.30
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in ./.venv/lib/python3.12/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 30.7 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.6.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Restart the kernel to apply the changes
# %reset -f

# %%
# import packages
import pandas as pd
import numpy as np
import cv2 as cv
import os
import time

from cuml.metrics import accuracy_score
from cuml.model_selection import train_test_split
from cuml.preprocessing import StandardScaler
from cuml.pipeline import Pipeline
from cuml.svm import SVC
from skimage.feature import hog
from sklearn.base import BaseEstimator, TransformerMixin

# %%
# Fetch dataset
# Suggested dir tree:
# .
# ├── submission.ipynb
# ├── train_ims
# ├── test_ims
# ├── train.csv
# ├── test.csv
dir = os.getcwd()
df = pd.read_csv('train.csv')

images = []
labels = []

for index, row in df.iterrows():
    img_path = os.path.join(dir, 'train_ims', row['im_name'])
    try:
        image = cv.imread(img_path, cv.IMREAD_ANYCOLOR)
    except:
        print(f"image {img_path} not found")
    # Add the flipeed images to augment the dataset
    images.append(cv.flip(image, 1))
    images.append(cv.flip(image, 0))
    images.append(cv.flip(image, -1))
    images.append(image)
    for i in range(4): labels.append(row['label'])

images = np.array(images)
labels = np.array(labels)
# X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
class Preprocessor(BaseEstimator, TransformerMixin):
    """
    This preprocessor aims to strengthen the edge details of the image 
    by combining HOG information from RGB channels respectively and 
    the original image.
    """
    def __init__(self):
        super().__init__()
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        features = []
        for image in X:
            r, g, b = cv.split(image)
            hog_r = hog(r, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=False)
            hog_g = hog(g, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=False)
            hog_b = hog(b, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=False)
            hog_features = np.concatenate((hog_r, hog_g, hog_b))

            image = cv.resize(image, (16,16))
            feature = np.hstack((image.flatten(), hog_features))
            features.append(feature)
        features = np.array(features)
        print(features.shape)
        return features

# %%
# Intialize the pipeline for training
pipeline = Pipeline([
    ('preprocessor', Preprocessor()),
    ('scaler', StandardScaler()),
    ('classifier', SVC(C=30, kernel='rbf', gamma='scale', random_state=42)),
])

# %%
# Training
start_time = time.time()
# pipeline.fit(X_train, y_train)
pipeline.fit(images, labels)
end_time = time.time()

print("Full training completed.")
print(f"Training time: {end_time - start_time} seconds")
print()
# Out:
# (200000, 1740)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Predicting
test_df = pd.read_csv('test.csv')
test_images = []
test_names = []

for index, row in test_df.iterrows():
    img_path = os.path.join(dir, 'test_ims', row['im_name'])
    try:
        image = cv.imread(img_path, cv.IMREAD_ANYCOLOR)
    except:
        print(f"image {img_path} not found")
    test_images.append(image)
    test_names.append(row['im_name'])

X_test = np.array(test_images)

start_time = time.time()
y_test_pred = pipeline.predict(X_test)
end_time = time.time()

# %%
# Save the result to submission.csv
output_df = pd.DataFrame({
    'im_name': test_names,
    'label': y_test_pred
})
output_df.to_csv('submission.csv', index=False)
print("submission.csv saved.")
print()
